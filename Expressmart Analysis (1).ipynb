# %% [markdown]
# ## Leveraging Analytics to Improve Sales and Customer Touchpoints at ExpressMart

# %%
![Image Description](Downloads/EDA 1/back.11.jpg)
# Out:
# '[Image' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### INTRODUCTION:
#
# This report analyses transactional data from __Express Mart__, a growing e-commerce and retail business operating in major cities such as Los Angeles, Atlanta, Dallas, New York City, and San Francisco. Although Express Mart has consistently achieved strong sales figures, management seeks to enhance overall business performance by understanding customer purchase behaviour, identifying sales trends, and optimising operational efficiency across its locations.
#
# The dataset under review comprises ***185,95*0** transaction records, capturing detailed information on product sales, quantity ordered, pricing, sales timing, and geographic distribution.
#
#
# #### Objective:
# The primary objective of this analysis is to:
#
# - Identify key products and customer purchasing patterns to maximise revenue.
# - Highlight peak sales periods to better align operational staffing and marketing strategies.
# - Detect potential inefficiencies such as order duplication or stock mismanagement.
# - Provide strategic recommendations that will drive Express Mart's profitability, customer satisfaction, and operational excellence.
#
# #### Problem Statement:
# While current sales metrics show healthy growth, Express Mart faces challenges related to:
#
# - Optimising staffing during peak hours to prevent missed sales opportunities.
# - Targeting marketing campaigns effectively based on customer behaviour.
# - Enhancing cross-selling tactics to boost average order value.
# - Maintaining clean and accurate sales data for financial reporting.
# Thus, a data-driven approach is required to refine operational strategies, increase conversion rates, and sustain long-term business growth.
#
# #### Insights
# 1. **Sales by Month**
# - Sales consistently peak during the holiday months, particularly in **November** and **December**.
# - Lower sales volumes are observed in February and March, indicating seasonal dips after the holiday rush.
#
# A well-timed marketing campaign launched in early November could maximise holiday season sales even further.
#
# 2. **Sales by City**
# Top-performing cities include:
#
# - San Francisco lead by  **\ 8,262,203.91** in sales
# -  New York City had **\ 5,452,570.80** in sales
# - Los Angeles followed by **\ 4,664,317.43** in sales
# - Poland and Austin  had lower sales, around **\2,320,490.61** and **\1,819,581.75**, indicating different customer  base and regional preferrences
# Cities like Seattle and Atlanta show strong potential for growth, but currently underperform relative to their population size.
#
# As such, there is a need to intensify local marketing and promotions in Atlanta and Seattle could tap into unmet market demand.
#
#
# 3.  **Top 5 Products by Sales**
#  MacBook Pro Laptop had the highest sales value of **\8037600.00**, followed by iPhone and Thinkpad with **\4,794,300.00** and **\4,129,958.70 respectivey.
#
# 4. **Sales by Quarter**
# - Quarter 4 (**October - December**) shows the highest overall sales of about **\11,549,773.42**, driven largely by holiday shopping.
#
# - Quarter 1 (January - March) reflects the lowest performance, indicating a post-holiday slowdown.
#
# - Sales dipped in **September** to **\2,097,560.13**,indicating that it was one of the slowest sales month.
#
#
# 5. **Quantity Ordered by Hour**
# - The majority of purchases occur between**11 AM** and **7 PM**, with peaks around **12 PM (lunchtime)** and **late afternoon (5 PM - 6 PM)**.
#
# - Early mornings (**before 9 AM**) and late nights (**after 9 PM**) show significantly fewer transactions.
#
#
# #### Key Trends Observed:
# 1. Product Sales Patterns: High-ticket items like the MacBook Pro Laptop dominate individual sale values, while lower-cost accessories such as USB-C Charging Cables can also generate high volume sales.
#
# 2. Location Performance: Sales are concentrated in key cities such as New York City, San Francisco, Atlanta, Los Angeles, and Dallas.
#
# 3. Time-Based Trends: Sales activity peaks during midday to evening hours (typically 11 AM to 7 PM), indicating optimal windows for operational and marketing focus.
#
# 4. Holiday Effect: There is a noticeable increase in sales volume during the holiday season (November–December), consistent with broader retail industry trends.
#
#
# ####  Recommendations:
# 1. Increase Staffing During Peak Hours (11 AM and 7 PM) by 30%–40% during these hours, as shorter wait times and more sales support can convert more browsers into buyers.
# 2. Organise Promotional Campaigns
# Type (a) :
# - Limited-time discounts, flash sales  (e.g., "20% off from 5 PM to 8 PM") to create urgency.
# - Organise Bundle Promotions, e.g, buy one premium product and get 20% off an accessory
# - Organise Holiday Campaigns that target big seasons like Black Friday, Christmas, Back-to-School, and New Year Sales.
#
# Type(b):
#
# - Email Marketing (target previous buyers with related products.
# - Social Media Ads (Instagram, Facebook) with time-limited offers.
#
# 3. Pair High-Demand, Low-Cost Accessories with Big-Ticket Items. e.g. MacBook Pro Laptop → USB-C Charging Cable or 27in FHD Monitor,iPhone Products → Wired Headphones and Apple AirPods
#
# 4. Geographical Expansion Strategy
# - Increase regional advertising spending by 20%–30% in (New York City,San Francisco, Atlanta) high-performing cities.
# - For underperforming regions, launch city-specific promotions to boost brand visibility.
#
# 6. Increase stock for high-volume, fast-selling products like USB-C Charging Cables, Wired Headphones, and 27-inch Monitors.
#
# 7. Monitor low-selling SKUS and reduce overstock risks by discounting slow-moving items.

# %%
# importing libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset loading 
expressmart_dt = pd.read_excel('ExpressMartData.TOT.xlsx')

# %%
# showing the first 5 rows 
expressmart_dt.head()
# Out:
#    Order ID               Product  Quantity Ordered  Price Each Order Date  \
# 0    295665    Macbook Pro Laptop                 1     1700.00 2019-12-30
# 1    295666    LG Washing Machine                 1      600.00 2019-12-29
# 2    295667  USB-C Charging Cable                 1       11.95 2019-12-12
# 3    295668      27in FHD Monitor                 1      149.99 2019-12-22
# 4    295669  USB-C Charging Cable                 1       11.95 2019-12-18
#
#                          Purchase Address      Time    Sales
# 0  136 Church St, New York City, NY 10001  00:01:00  1700.00
# 1     562 2nd St, New York City, NY 10001  07:03:00   600.00
# 2    277 Main St, New York City, NY 10001  18:21:00    11.95
# 3     410 6th St, San Francisco, CA 94016  15:13:00   149.99
# 4           43 Hill St, Atlanta, GA 30301  12:38:00    11.95

# %%
# rows and columns numbers
expressmart_dt.shape
# Out:
# (185950, 8)

# %%
# date information
expressmart_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  int64
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  185950 non-null  object
#  6   Time              185950 non-null  object
#  7   Sales             185950 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(3)
# memory usage: 11.3+ MB

# %%
# checking for null valus 
expressmart_dt.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Time                0
# Sales               0
# dtype: int64

# %%
# summary statistics
expressmart_dt.describe( )
# Out:
#             Order ID  Quantity Ordered     Price Each  \
# count  185950.000000     185950.000000  185950.000000
# mean   230417.569379          1.124383     184.399735
# min    141234.000000          1.000000       2.990000
# 25%    185831.250000          1.000000      11.950000
# 50%    230367.500000          1.000000      14.950000
# 75%    275035.750000          1.000000     150.000000
# max    319670.000000          9.000000    1700.000000
# std     51512.737110          0.442793     332.731330
#
#                           Order Date          Sales
# count                         185950  185950.000000
# mean   2019-07-18 07:00:22.109169152     185.490917
# min              2019-01-01 00:00:00       2.990000
# 25%              2019-04-16 00:00:00      11.950000
# 50%              2019-07-17 00:00:00      14.950000
# 75%              2019-10-26 00:00:00     150.000000
# max              2020-01-01 00:00:00    3400.000000
# std                              NaN     332.919771

# %%
#summary statistics ( categorical column)
expressmart_dt.describe( include ='O')
# Out:
#                      Product                        Purchase Address      Time
# count                 185950                                  185950    185950
# unique                    19                                  140787      1440
# top     USB-C Charging Cable  193 Forest St, San Francisco, CA 94016  11:58:00
# freq                   21903                                       9       252

# %%
# duplicates checking
expressmart_dt.duplicated().sum()
# Out:
# 264

# %%
# displaying duplicated rows
expressmart_dt[ expressmart_dt.duplicated()].sort_values(by='Product')
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 43089     193916            20in Monitor                 1      109.99
# 134593    276692            20in Monitor                 1      109.99
# 64968     171322            20in Monitor                 1      109.99
# 13557     308671  27in 4K Gaming Monitor                 1      389.99
# 11258     306458  27in 4K Gaming Monitor                 1      389.99
# ...          ...                     ...               ...         ...
# 146180    150216        Wired Headphones                 1       11.99
# 83375     195045        Wired Headphones                 1       11.99
# 10183     305423        Wired Headphones                 1       11.99
# 43717     150925                  iPhone                 1      700.00
# 177691    214976                  iPhone                 1      700.00
#
#        Order Date                          Purchase Address      Time   Sales
# ...

# %%
# extracting hours from the time column
expressmart_dt['Hour']= pd.to_datetime(expressmart_dt['Time'],format ='%H:%M:%S').dt.hour
expressmart_dt.head()
# Out:
#    Order ID               Product  Quantity Ordered  Price Each Order Date  \
# 0    295665    Macbook Pro Laptop                 1     1700.00 2019-12-30
# 1    295666    LG Washing Machine                 1      600.00 2019-12-29
# 2    295667  USB-C Charging Cable                 1       11.95 2019-12-12
# 3    295668      27in FHD Monitor                 1      149.99 2019-12-22
# 4    295669  USB-C Charging Cable                 1       11.95 2019-12-18
#
#                          Purchase Address      Time    Sales  Hour
# 0  136 Church St, New York City, NY 10001  00:01:00  1700.00     0
# 1     562 2nd St, New York City, NY 10001  07:03:00   600.00     7
# 2    277 Main St, New York City, NY 10001  18:21:00    11.95    18
# 3     410 6th St, San Francisco, CA 94016  15:13:00   149.99    15
# 4           43 Hill St, Atlanta, GA 30301  12:38:00    11.95    12

# %%
# Extracting the month column 
expressmart_dt['Month']= expressmart_dt['Order Date'].dt.strftime('%b')
expressmart_dt[['Month','Order Date']]
# Out:
#        Month Order Date
# 0        Dec 2019-12-30
# 1        Dec 2019-12-29
# 2        Dec 2019-12-12
# 3        Dec 2019-12-22
# 4        Dec 2019-12-18
# ...      ...        ...
# 185945   Jun 2019-06-07
# 185946   Jun 2019-06-01
# 185947   Jun 2019-06-22
# 185948   Jun 2019-06-26
# 185949   Jun 2019-06-25
#
# [185950 rows x 2 columns]

# %%
# function to classify AM/PM
def classify_am_pm(time):
    return 'AM' if time. hour < 12 else 'PM'
    
 # applying the AM/PM function to the column
    expressmart_dt['AM/PM']= expressmart_dt['Time'].apply (classify_am_pm)

    expressmart_dt[['Time',' AM/PM']]

# %%
# function to classify AM/PM
def classify_am_pm(time):
    return 'AM' if time.hour < 12 else 'PM'
    
 # applying the AM/PM function to the column
expressmart_dt['AM/PM'] = expressmart_dt['Time'].apply (classify_am_pm)

expressmart_dt[['Time', 'AM/PM']]
# Out:
#             Time AM/PM
# 0       00:01:00    AM
# 1       07:03:00    AM
# 2       18:21:00    PM
# 3       15:13:00    PM
# 4       12:38:00    PM
# ...          ...   ...
# 185945  19:02:00    PM
# 185946  19:29:00    PM
# 185947  18:57:00    PM
# 185948  18:35:00    PM
# 185949  14:33:00    PM
#
# [185950 rows x 2 columns]

# %%
# extracting quarter and formatting as qtr1,qtr2.
expressmart_dt['Quarter']= 'Qtr' + ' ' + expressmart_dt['Order Date'].dt.quarter.astype(str)
expressmart_dt[['Order Date','Quarter']]
# Out:
#        Order Date Quarter
# 0      2019-12-30   Qtr 4
# 1      2019-12-29   Qtr 4
# 2      2019-12-12   Qtr 4
# 3      2019-12-22   Qtr 4
# 4      2019-12-18   Qtr 4
# ...           ...     ...
# 185945 2019-06-07   Qtr 2
# 185946 2019-06-01   Qtr 2
# 185947 2019-06-22   Qtr 2
# 185948 2019-06-26   Qtr 2
# 185949 2019-06-25   Qtr 2
#
# [185950 rows x 2 columns]

# %%
# extracting year from Order_Date 
expressmart_dt['Year'] = expressmart_dt['Order Date'].dt.year
expressmart_dt[['Order Date', 'Year']]
# Out:
#        Order Date  Year
# 0      2019-12-30  2019
# 1      2019-12-29  2019
# 2      2019-12-12  2019
# 3      2019-12-22  2019
# 4      2019-12-18  2019
# ...           ...   ...
# 185945 2019-06-07  2019
# 185946 2019-06-01  2019
# 185947 2019-06-22  2019
# 185948 2019-06-26  2019
# 185949 2019-06-25  2019
#
# [185950 rows x 2 columns]

# %%
expressmart_dt
# Out:
#         Order ID                 Product  Quantity Ordered  Price Each  \
# 0         295665      Macbook Pro Laptop                 1     1700.00
# 1         295666      LG Washing Machine                 1      600.00
# 2         295667    USB-C Charging Cable                 1       11.95
# 3         295668        27in FHD Monitor                 1      149.99
# 4         295669    USB-C Charging Cable                 1       11.95
# ...          ...                     ...               ...         ...
# 185945    222905  AAA Batteries (4-pack)                 1        2.99
# 185946    222906        27in FHD Monitor                 1      149.99
# 185947    222907    USB-C Charging Cable                 1       11.95
# 185948    222908    USB-C Charging Cable                 1       11.95
# 185949    222909  AAA Batteries (4-pack)                 1        2.99
#
#        Order Date                        Purchase Address      Time    Sales  \
# ...

# %%
# extracting city from the purchase address column
expressmart_dt['City'] = expressmart_dt['Purchase Address'].apply(lambda x: x.split(',')[1].strip())
expressmart_dt['City'].unique()
# Out:
# array(['New York City', 'San Francisco', 'Atlanta', 'Portland', 'Dallas',
#        'Los Angeles', 'Boston', 'Austin', 'Seattle'], dtype=object)

# %%
# calculating total quantities
Total_Quantity =expressmart_dt['Quantity Ordered'].sum()

# calculating total sales
Total_sales = expressmart_dt['Sales'].sum()

# Calculating the total number of unique products 
Total_products = expressmart_dt['Product'].nunique()

print(f"Total Quantity:{Total_Quantity}")
print(f"Total Sales :{Total_sales}")
print(f"Total Product:{Total_products}")
# Out:
# Total Quantity:209079
# Total Sales :34492035.97
# Total Product:19

# %% [markdown]
# ### Visuals creation

# %%
# growth and sales 
monthly_sales = expressmart_dt.groupby('Month')['Sales'].sum().reset_index()

# histogram plotting using seaborn
plt.figure(figsize=(10,6))
sns.barplot(x='Month',y='Sales', data=monthly_sales, palette='viridis',hue= 'Month',legend=False
)

plt.title('Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
# sales by city
city_sales = expressmart_dt.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(x='City',y='Sales',data=city_sales, palette='magma' , hue= 'City',legend=False)

plt.xlabel('City')
plt.ylabel('Sales')
plt.title('Sales by City')
plt.xticks(rotation=45)
plt.show()

# %%
# grouping sales and product
product_sales = expressmart_dt.groupby('Product')['Sales'].sum().reset_index()

# Sort to get the top 5 products by sales
top_5_products = product_sales.sort_values(by='Sales', ascending=False).head(5)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x='Sales', y='Product', data=top_5_products, palette='coolwarm', hue='Sales')

plt.title('Top 5 Best-Selling Products')
plt.xlabel('Total Sales')
plt.ylabel('Product')
plt.xticks(rotation=45)
plt.show()

# %%
# quarterly sales
quarterly_sales = expressmart_dt.groupby('Quarter')['Sales'].sum().sort_index()

plt.figure(figsize=(12,8))
quarterly_sales.plot( kind='pie',autopct='%1.1f%%',colors=sns.color_palette('cubehelix'),startangle=100)

plt.title('Quarterly Sales')
plt.show()

# %%
 # What is the quantity ordered per an hour?
hourly_quantity = expressmart_dt.groupby('Hour')['Quantity Ordered'].sum()

plt.figure(figsize=(12,6))
sns.lineplot( x=hourly_quantity.index,y=hourly_quantity.values, marker='o',linestyle='-',color='b')

plt.title('Quantity Ordered Per Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Quantity Ordered')
plt.grid(True)
plt.xticks(range(0,24))
plt.show()

# %%
# periodic sales 

periodic_sales= expressmart_dt.groupby('AM/PM')['Sales'].sum()
periodic_sales.plot( kind='pie',autopct='%1.1f%%',colors=sns.color_palette('husl'),startangle=100)

plt.title('Periodic Sales')
plt.show()
